# %%
# Pip install method (recommended)
# !pip install ultralytics==8.0.196
# Out:
# Requirement already satisfied: ultralytics==8.0.196 in /opt/homebrew/lib/python3.11/site-packages (8.0.196)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (3.8.2)
# Requirement already satisfied: numpy>=1.22.2 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (1.24.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (4.7.0.72)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (4.66.2)
# Requirement already satisfied: pandas>=1.1.4 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (2.2.0)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (0.13.2)
# Requirement already satisfied: psutil in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics==8.0.196) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2023.7.22)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.11.0)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.3)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.3)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2024.3.1)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics==8.0.196) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       2 display.clear_output()
#       4 import ultralytics
# ----> 5 ultralytics.checks()
#       7 from ultralytics import YOLO
#       9 from IPython.display import display, Image
#
# AttributeError: module 'ultralytics' has no attribute 'checks'

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/best.pt conf=0.25 source={HOME}/images save=True
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/3 /content/images/Screenshot 2024-04-18 at 8.22.19 PM.jpg: 448x800 1 ball, 561.7ms
# image 2/3 /content/images/Screenshot 2024-04-18 at 8.25.39 PM.jpg: 448x800 2 balls, 514.4ms
# image 3/3 /content/images/Screenshot 2024-04-18 at 8.29.27 PM.jpg: 800x480 1 ball, 571.2ms
# Speed: 5.8ms preprocess, 549.1ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict2/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="XaYRaTIxrFcAN0CfHjEN")
project = rf.workspace("ahmed-ws").project("ball-detection-3afaq")
version = project.version(3)
dataset = version.download("yolov8")
